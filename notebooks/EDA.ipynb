# %%
import pandas as pd

# %%
df = pd.read_csv(r"../data/raw/Food_Nutrition_Dataset.csv")
df.head()
# Out:
#         food_name        category  calories  protein  carbs   fat  iron  \
# 0  Apple, candied          Apples     134.0     1.34  29.61  2.15  0.12
# 1      Apple, raw          Apples      61.0     0.17  14.80  0.15  0.03
# 2    Apple, dried    Dried fruits     243.0     0.93  65.89  0.32  1.40
# 3    Crisp, apple  Cakes and pies     215.0     2.81  30.18  9.59  1.00
# 4    Apple, baked          Apples     113.0     0.32  22.70  3.08  0.19
#
#    vitamin_c
# 0        3.6
# 1        4.6
# 2        3.9
# 3        0.6
# 4        3.9

# %%
df.shape
# Out:
# (205, 8)

# %%
df.describe()
# Out:
#           calories     protein       carbs         fat        iron   vitamin_c
# count   205.000000  205.000000  205.000000  205.000000  203.000000  202.000000
# mean    243.790244    2.852829   25.573366    6.018000    0.851330   13.694554
# std     283.580451    3.357243   20.119102    9.694549    1.103369   18.503094
# min      16.000000    0.000000    1.790000    0.000000    0.000000    0.000000
# 25%      62.000000    0.640000   11.200000    0.200000    0.205000    1.625000
# 50%     166.000000    1.710000   17.220000    1.180000    0.410000    7.450000
# 75%     296.000000    3.200000   37.550000    9.390000    1.080000   17.375000
# max    1460.000000   17.800000   85.130000   74.020000    9.090000  136.000000

# %%
df['category'].unique()
# Out:
# array(['Apples', 'Dried fruits', 'Cakes and pies', 'Apple juice',
#        'Baked Products', 'Other fruits and fruit salads', 'Sweets',
#        'Fruits and Fruit Juices', 'Coleslaw, non-lettuce salads',
#        'Bananas', 'Fruit drinks', 'Pudding',
#        'Ice cream and frozen dairy desserts',
#        'American Indian/Alaska Native Foods',
#        'Vegetables and Vegetable Products',
#        'Other vegetables and combinations', 'Snacks', 'Citrus fruits',
#        'Liquor and cocktails', 'Stir-fry and soy-based sauce mixtures',
#        'Beverages', 'Grapes', 'Other fruit juice', 'Rice mixed dishes',
#        'Meat mixed dishes', 'Mango and papaya', 'Dairy and Egg Products',
#        'Tomato-based condiments', 'Pears', 'Strawberries', 'Fast Foods',
#        'Jams, syrups, toppings', 'Flavored milk, reduced fat',
#        'Flavored milk, whole', 'Legumes and Legume Products',
#        'Blueberries and other berries',
#        'French fries and other fried white potatoes',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   food_name  205 non-null    object
#  1   category   205 non-null    object
#  2   calories   205 non-null    float64
#  3   protein    205 non-null    float64
#  4   carbs      205 non-null    float64
#  5   fat        205 non-null    float64
#  6   iron       203 non-null    float64
#  7   vitamin_c  202 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 12.9+ KB

# %%
df.isnull().sum()
# Out:
# food_name    0
# category     0
# calories     0
# protein      0
# carbs        0
# fat          0
# iron         2
# vitamin_c    3
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# food_name    0
# category     0
# calories     0
# protein      0
# carbs        0
# fat          0
# iron         0
# vitamin_c    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#         food_name        category  calories  protein  carbs   fat  iron  \
# 0  Apple, candied          Apples     134.0     1.34  29.61  2.15  0.12
# 1      Apple, raw          Apples      61.0     0.17  14.80  0.15  0.03
# 2    Apple, dried    Dried fruits     243.0     0.93  65.89  0.32  1.40
# 3    Crisp, apple  Cakes and pies     215.0     2.81  30.18  9.59  1.00
# 4    Apple, baked          Apples     113.0     0.32  22.70  3.08  0.19
#
#    vitamin_c
# 0        3.6
# 1        4.6
# 2        3.9
# 3        0.6
# 4        3.9

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['protein'], kde=True)
plt.title("Distribution of Protein")
plt.show()

# %%
sns.boxplot(x=df['calories'])
plt.show()

# %%
df['category'].value_counts()
# Out:
# category
# Fruits and Fruit Juices                             22
# Vegetables and Vegetable Products                   16
# Cakes and pies                                      12
# Yeast breads                                        11
# Fried vegetables                                     7
# Beverages                                            7
# Sweets                                               6
# Pears                                                5
# Baked Products                                       5
# Dried fruits                                         5
# Apples                                               4
# Other fruit juice                                    4
# Jams, syrups, toppings                               4
# Potato chips                                         4
# Fruit drinks                                         4
# Tomatoes                                             4
# Dips, gravies, other sauces                          4
# ...

# %%
sns.scatterplot(x='fat', y='calories', data=df)
plt.show()

# %%
df.head(1)
# Out:
#         food_name category  calories  protein  carbs   fat  iron  vitamin_c
# 0  Apple, candied   Apples     134.0     1.34  29.61  2.15  0.12        3.6

# %%
numeric_df = df[['calories', 'protein','carbs','fat', 'iron', 'vitamin_c']]
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation")
plt.show()

# %%
df['protein_per_100_cal'] = (df['protein'] / df['calories']) * 100

# %%
df.head()
# Out:
#         food_name        category  calories  protein  carbs   fat  iron  \
# 0  Apple, candied          Apples     134.0     1.34  29.61  2.15  0.12
# 1      Apple, raw          Apples      61.0     0.17  14.80  0.15  0.03
# 2    Apple, dried    Dried fruits     243.0     0.93  65.89  0.32  1.40
# 3    Crisp, apple  Cakes and pies     215.0     2.81  30.18  9.59  1.00
# 4    Apple, baked          Apples     113.0     0.32  22.70  3.08  0.19
#
#    vitamin_c  protein_per_100_cal
# 0        3.6             1.000000
# 1        4.6             0.278689
# 2        3.9             0.382716
# 3        0.6             1.306977
# 4        3.9             0.283186
